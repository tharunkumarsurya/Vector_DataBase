# %%
# this notebook is based on Pinecone v-5.0.0 and Python3.12.7

# %%
# MY_KEY = "....................................."

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key=MY_KEY)

# %%
# index creation
pc.create_index(name="insert", dimension=3, spec=ServerlessSpec(
    cloud="aws",
    region="us-east-1"
))

# %%
# upsert
idx = pc.Index("insert")

# %%
pc.list_indexes()
# Out:
# {'indexes': [{'deletion_protection': 'disabled',
#               'dimension': 3,
#               'host': 'insert-cffc582.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'insert',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}}]}

# %%
data = [('vec1', [1.0, 2.0, 3.0]), ('vec2', [11.0, 12.0, 13.0]), ('vec3', [31.0, 32.0, 33.0])]

# %%
idx.upsert(data)
# Out:
# {'upserted_count': 3}

# %%
# MY_KEY = ""

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key=MY_KEY)

# %%
# index creation 
pc.create_index(name="insert", dimension=3, spec=ServerlessSpec(
    cloud="aws",
    region="us-east-1"
))
# Out:
# {
#     "name": "insert",
#     "metric": "cosine",
#     "host": "insert-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "259e4e6869e624c4e4fafd14f6b1c5b6",
#             "date": "Tue, 21 Apr 2026 12:51:14 GMT",
#             "server": "Google Frontend",
#             "content-length": "379",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
# upsert
idx = pc.Index("insert")

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "insert",
#         "metric": "cosine",
#         "host": "insert-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
data = [('vec1', [1.0, 2.0, 3.0]), 
        ('vec2', [11.0, 12.0, 13.0]), 
        ('vec3', [31.0, 32.0, 33.0])]

# %%
idx.upsert(data)
# Out:
# UpsertResponse(upserted_count=3, _response_info={'raw_headers': {'date': 'Tue, 21 Apr 2026 12:54:24 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '48', 'x-pinecone-request-latency-ms': '287', 'x-envoy-upstream-service-time': '288', 'x-pinecone-response-duration-ms': '289', 'grpc-status': '0', 'server': 'envoy'}})
