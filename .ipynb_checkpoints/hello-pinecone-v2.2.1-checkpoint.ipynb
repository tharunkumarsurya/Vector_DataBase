# %%
import pinecone

# %%
pinecone.init(api_key = "your key", environment = "your env")

# %%
pinecone.create_index(name = "insert", dimension = 3)

# %%
pinecone.list_indexes()
# Out:
# ['insert']

# %%
vectors= [[1, 3, 4], [5, 6, 7], [8, 9, 0]]

# %%
vect_ids = ['vec1', 'vec2', 'vec3']

# %%
idx = pinecone.Index('insert')

# %%
idx.upsert([
    ('vec1', [1, 3, 4]),   # tuple . with id and vector
    ('vec2', [5, 6, 7]),
    ('vec3', [8, 9, 0])
    
    
])  # list of vectors
# Out:
# {'upserted_count': 3}

# %%
import pinecone
from pinecone import Pinecone

# %%
pc = Pinecone(
    # api_key=""
)

# %%
print(pc.list_indexes())
# Out:
# [{
#     "name": "test",
#     "metric": "cosine",
#     "host": "test-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null
# }]

# %%
# pinecone.init(api_key = "", environment = "us-east-1")

# %%
# pinecone.create_index(name = "hello-pinecone", dimension = 4)

# %%
from pinecone import Pinecone, ServerlessSpec

# pc = Pinecone(api_key="")

pc.create_index(
    name="hello-pinecone",
    dimension=4,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-west-2"
    )
)
# Out:
# {
#     "name": "hello-pinecone",
#     "metric": "cosine",
#     "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-west-2",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 4,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
# ...

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "hello-pinecone",
#         "metric": "cosine",
#         "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
vectors= [[1, 3, 4], [5, 6, 7], [8, 9, 0]]

# %%
vect_ids = ['vec1', 'vec2', 'vec3']

# %%
print(pc.list_indexes().names())
# Out:
# ['hello-pinecone']

# %%
index = pc.Index("hello-pinecone")

# %%
from pinecone import Pinecone

# pc = Pinecone(api_key="")
index = pc.Index("hello-pinecone")

# %%
idx = pc.Index('hello-pinecone')

# %%
idx.upsert([
    ('vec1', [1.0, 3.0, 4.0, 2.0]),   # tuple . with id and vector
    ('vec2', [5.0, 6.0, 7.0, 6.0]),
    ('vec3', [8.0, 9.0, 0.0, 4.0])
    
    
])  # list of vectors
# Out:
# UpsertResponse(upserted_count=3, _response_info={'raw_headers': {'date': 'Tue, 21 Apr 2026 12:14:44 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '60', 'x-pinecone-request-latency-ms': '170', 'x-envoy-upstream-service-time': '170', 'x-pinecone-response-duration-ms': '171', 'grpc-status': '0', 'server': 'envoy'}})
