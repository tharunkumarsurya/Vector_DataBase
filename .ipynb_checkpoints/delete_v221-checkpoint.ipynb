# %%
import pinecone
from tqdm.autonotebook import tqdm
from pinecone import Pinecone

# pc = Pinecone(api_key="")

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "test",
#         "metric": "cosine",
#         "host": "test-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "hello-pinecone",
#         "metric": "cosine",
#         "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
# ...

# %%
idx = pc.Index('insert')

# %%
idx.delete(ids = ['vec1'])  # 'vec1', vec2, vec3, vec33
# Out:
# {'_response_info': {'raw_headers': {'date': 'Wed, 22 Apr 2026 18:35:34 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-lsn': '7',
#    'x-pinecone-request-logical-size': '0',
#    'x-pinecone-request-latency-ms': '151',
#    'x-envoy-upstream-service-time': '151',
#    'x-pinecone-response-duration-ms': '153',
#    'grpc-status': '0',
#    'server': 'envoy'}}}

# %%
idx.delete(ids = ['vec1'])
# Out:
# {'_response_info': {'raw_headers': {'date': 'Wed, 22 Apr 2026 18:36:14 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-lsn': '8',
#    'x-pinecone-request-logical-size': '0',
#    'x-pinecone-request-latency-ms': '145',
#    'x-envoy-upstream-service-time': '157',
#    'x-pinecone-response-duration-ms': '159',
#    'grpc-status': '0',
#    'server': 'envoy'}}}

# %%
idx.delete(delete_all=True)
# Out:
# {'_response_info': {'raw_headers': {'date': 'Wed, 22 Apr 2026 18:36:29 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-latency-ms': '143',
#    'x-envoy-upstream-service-time': '144',
#    'x-pinecone-response-duration-ms': '145',
#    'grpc-status': '0',
#    'server': 'envoy'}}}
