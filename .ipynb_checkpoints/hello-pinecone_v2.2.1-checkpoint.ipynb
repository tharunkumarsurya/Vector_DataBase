# %%
import pinecone 
from pinecone import Pinecone, ServerlessSpec

# %%
# pinecone.init(api_key = "your key", environment = "your env")
pc = Pinecone(
    # api_key=""
)

# %%
from pinecone import Pinecone, ServerlessSpec

# pc = Pinecone(api_key="")

pc.create_index(
    name="hello-pinecone",
    dimension=4,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-west-2"
    )
)
# Out:
# {
#     "name": "hello-pinecone",
#     "metric": "cosine",
#     "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-west-2",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 4,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "c4e208d7cb5ec8e87e1b0d491ef64897",
#             "date": "Wed, 22 Apr 2026 17:54:18 GMT",
#             "server": "Google Frontend",
#             "content-length": "395",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
# pc = Pinecone(api_key="")

pc.create_index(
    name="insert",
    dimension=4,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-west-2"
    )
)
# Out:
# {
#     "name": "insert",
#     "metric": "cosine",
#     "host": "insert-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-west-2",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 4,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "6ff34e9063ee9a1525ab1cf728af87f5",
#             "date": "Wed, 22 Apr 2026 17:55:40 GMT",
#             "server": "Google Frontend",
#             "content-length": "379",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "test",
#         "metric": "cosine",
#         "host": "test-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "text"
#             },
#             "dimension": 1024,
#             "metric": "cosine",
#             "write_parameters": {
#                 "dimension": 1024,
#                 "input_type": "passage",
#                 "truncate": "END"
#             },
#             "read_parameters": {
#                 "dimension": 1024,
#                 "input_type": "query",
#                 "truncate": "END"
#             },
#             "vector_type": "dense"
#         }
#     },
#     {
#         "name": "hello-pinecone",
#         "metric": "cosine",
#         "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "insert",
#         "metric": "cosine",
#         "host": "insert-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
vectors= [[1, 3, 4], [5, 6, 7], [8, 9, 0]]

# %%
vect_ids = ['vec1', 'vec2', 'vec3']

# %%
idx = pc.Index('hello-pinecone')

# %%
idx.upsert([
    ('vec1', [1.0, 3.0, 4.0, 6.0]),   # tuple . with id and vector
    ('vec2', [5.0, 6.0, 7.0, 9.0]),
    ('vec3', [8.0, 9.0, 0.0, 4.0])
    
    
])  # list of vectors
# Out:
# UpsertResponse(upserted_count=3, _response_info={'raw_headers': {'date': 'Wed, 22 Apr 2026 18:03:23 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '60', 'x-pinecone-request-latency-ms': '386', 'x-envoy-upstream-service-time': '387', 'x-pinecone-response-duration-ms': '388', 'grpc-status': '0', 'server': 'envoy'}})
