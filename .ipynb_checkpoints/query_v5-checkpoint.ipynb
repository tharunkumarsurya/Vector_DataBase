# %%
from pinecone import Pinecone 
from tqdm.autonotebook import tqdm 

# API_KEY = ""

# %%
pc = Pinecone(api_key = API_KEY)

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "insert",
#         "metric": "cosine",
#         "host": "insert-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
idx = pc.Index('insert')

# %%
idx.upsert([
    ('vec1', [1.0, 3.0, 44.0]),   # update if vec1 is already in DB
    ('vec2', [5.0, 6.0, 77.0]),   # update 
    ('vec33', [8.0, 9.0, 0.0])    # insert if vec33 is a new entry
    
    
])  # list of vectors
# Out:
# UpsertResponse(upserted_count=3, _response_info={'raw_headers': {'date': 'Tue, 21 Apr 2026 18:53:54 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '6', 'x-pinecone-request-logical-size': '49', 'x-pinecone-request-latency-ms': '197', 'x-envoy-upstream-service-time': '201', 'x-pinecone-response-duration-ms': '202', 'grpc-status': '0', 'server': 'envoy'}})

# %%
idx.query(vector = [0, 0 , 0], top_k=5, include_values = True)  # previously vectors could be passed as positional arg, now keyword
# Out:
# QueryResponse(matches=[{'id': 'A', 'score': 0.0, 'values': [0.1, 0.1, 0.1]}, {'id': 'B', 'score': 0.0, 'values': [0.2, 0.2, 0.2]}, {'id': 'C', 'score': 0.0, 'values': [0.3, 0.3, 0.3]}, {'id': 'D', 'score': 0.0, 'values': [0.4, 0.4, 0.4]}, {'id': 'vec3', 'score': 0.0, 'values': [31.0, 32.0, 33.0]}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Tue, 21 Apr 2026 18:55:16 GMT', 'content-type': 'application/json', 'content-length': '285', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '6', 'x-pinecone-request-latency-ms': '9', 'x-envoy-upstream-service-time': '10', 'x-pinecone-response-duration-ms': '11', 'grpc-status': '0', 'server': 'envoy'}})
