# %%
import pinecone
from pinecone import Pinecone

# pc = Pinecone(api_key ="" )

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "test",
#         "metric": "cosine",
#         "host": "test-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "text"
#             },
#             "dimension": 1024,
# ...

# %%
vectors= [[1, 3, 4], [5, 6, 7], [8, 9, 0]]
vect_ids = ['vec1', 'vec2', 'vec3']

# %%
idx = pc.Index('hello-pinecone')

# %%
idx.upsert([
    ('vec1', [1.0, 3.0, 44.0,5.0]),   # update because vec1 is already in DB
    ('vec2', [5.0, 6.0, 77.0,5.0]),   # update
    ('vec33', [8.0, 9.0, 0.0,5.0])    # insert
    
    
])  # list of vectors
# Out:
# UpsertResponse(upserted_count=3, _response_info={'raw_headers': {'date': 'Wed, 22 Apr 2026 18:15:28 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '3', 'x-pinecone-request-logical-size': '61', 'x-pinecone-request-latency-ms': '152', 'x-envoy-upstream-service-time': '153', 'x-pinecone-response-duration-ms': '155', 'grpc-status': '0', 'server': 'envoy'}})

# %%
# idx.query([0.0, 0.0 , 0.0, 0.0], top_k=5, include_values = True)


idx.query(
    vector=[0.0, 0.0, 0.0, 0.0],
    top_k=4,
    include_values=True
)
# Out:
# QueryResponse(matches=[{'id': 'vec2', 'score': 0.0, 'values': [5.0, 6.0, 77.0, 5.0]}, {'id': 'vec33', 'score': 0.0, 'values': [8.0, 9.0, 0.0, 5.0]}, {'id': 'vec3', 'score': 0.0, 'values': [8.0, 9.0, 0.0, 4.0]}, {'id': 'vec1', 'score': 0.0, 'values': [1.0, 3.0, 44.0, 5.0]}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Wed, 22 Apr 2026 18:18:53 GMT', 'content-type': 'application/json', 'content-length': '240', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '3', 'x-pinecone-request-latency-ms': '6', 'x-envoy-upstream-service-time': '7', 'x-pinecone-response-duration-ms': '9', 'grpc-status': '0', 'server': 'envoy'}})
