# %%
# MY_KEY = "4drandomrandom............."

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key = MY_KEY)

# %%
pc.list_indexes()
# Out:
# {'indexes': []}

# %%
pc.create_index(name="test", 
               dimension = 3, 
               spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )  ) # free tier use only us-east-1

# %%
pc.list_indexes()
# Out:
# {'indexes': [{'deletion_protection': 'disabled',
#               'dimension': 3,
#               'host': 'test-075603f.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'test',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}}]}

# %%
# MY_KEY = ""
# !pip install pinecone

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
pc = Pinecone(api_key = MY_KEY)  # no  need for other parameters

# %%
pc.list_indexes()
# Out:
# []

# %%
pc.create_index(name="test",
               dimension=3,
               spec = ServerlessSpec(
                   cloud="aws",
                   region="us-east-1"
               ) )   # for free tier use only us-east-1
# Out:
# {
#     "name": "test",
#     "metric": "cosine",
#     "host": "test-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
# ...

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "test",
#         "metric": "cosine",
#         "host": "test-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]
