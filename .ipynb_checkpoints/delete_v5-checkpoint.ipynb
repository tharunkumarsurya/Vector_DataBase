# %%
# API_KEY = ""

# %%
from pinecone import Pinecone 
pc = Pinecone(api_key = API_KEY)

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "insert",
#         "metric": "cosine",
#         "host": "insert-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
idx = pc.Index('insert')

# %%
idx.delete(ids = ['vec33'])  # 'vec1', vec2, vec3, vec33
# Out:
# {'_response_info': {'raw_headers': {'date': 'Tue, 21 Apr 2026 19:04:03 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-lsn': '7',
#    'x-pinecone-request-logical-size': '0',
#    'x-pinecone-request-latency-ms': '245',
#    'x-envoy-upstream-service-time': '247',
#    'x-pinecone-response-duration-ms': '248',
#    'grpc-status': '0',
#    'server': 'envoy'}}}

# %%
idx.delete(ids = ['vec1'])
# Out:
# {'_response_info': {'raw_headers': {'date': 'Tue, 21 Apr 2026 19:04:47 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-lsn': '8',
#    'x-pinecone-request-logical-size': '0',
#    'x-pinecone-request-latency-ms': '176',
#    'x-envoy-upstream-service-time': '177',
#    'x-pinecone-response-duration-ms': '178',
#    'grpc-status': '0',
#    'server': 'envoy'}}}

# %%
idx.delete(delete_all=True)
# Out:
# {'_response_info': {'raw_headers': {'date': 'Tue, 21 Apr 2026 19:05:09 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-latency-ms': '82',
#    'x-envoy-upstream-service-time': '83',
#    'x-pinecone-response-duration-ms': '84',
#    'grpc-status': '0',
#    'server': 'envoy'}}}
