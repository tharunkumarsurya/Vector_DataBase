# %% [markdown]
# # NER Powered Semantic Search Using Pinecone v5.0.0

# %% [markdown]
# ### Setup Environment

# %%
# init pinecone

from pinecone import Pinecone, ServerlessSpec
# API_KEY = "YOUR API KEY"
# pc = Pinecone(api_key = "")

index = pc.Index("test2")

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "medium-data",
#         "metric": "cosine",
#         "host": "medium-data-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 768,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "medium-datas",
#         "metric": "cosine",
#         "host": "medium-datas-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 768,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "test2",
#         "metric": "cosine",
#         "host": "test2-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 384,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "hello-pinecone",
#         "metric": "cosine",
#         "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "insert",
#         "metric": "cosine",
#         "host": "insert-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
# clean up pinecone index, after deleting all vectors if you run it again you will get error

# index.delete(delete_all=True)

# %%
# delete index , dimension no longer useful
# pc.delete_index("test")

# %%
# load libraries for NER 

# from transformers import AutoTokenizer, AutoModelForTokenClassification
# from transformers import pipeline
# import torch

from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
import torch

# %% [markdown]
# ### NER Engine

# %%
import os
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# %%
# init NER engine

# model_id = 'dslim/bert-base-NER'

# tokenizer = AutoTokenizer.from_pretrained(model_id)
# model = AutoModelForTokenClassification.from_pretrained(model_id)

# # nlp pipeline

# nlp = pipeline('ner',
#               model=model,
#               tokenizer=tokenizer,
#               aggregation_strategy= 'max',
#               device= 'cpu') 
# # nlp("Bill Gates is the founder of Microsoft")


model_id = 'dslim/bert-base-NER'

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForTokenClassification.from_pretrained(model_id)

nlp = pipeline('ner',
              model=model,
              tokenizer=tokenizer,
              aggregation_strategy='max',
              device='cpu')
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dslim/bert-base-NER
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ### Retriever

# %%
# !pip install --upgrade pyarrow
# !pip install pyarrow==15.0.2 datasets==2.19.1 sentence-transformers
import pyarrow as pa
print(pa.__version__)
# Out:
# 15.0.2

# %%
# load libraries for retriever

# from sentence_transformers import SentenceTransformer


# # https://huggingface.co/flax-sentence-embeddings/all_datasets_v3_mpnet-base
# retriever = SentenceTransformer(
#     "flax-sentence-embeddings/all_datasets_v3_mpnet-base")


from sentence_transformers import SentenceTransformer

retriever = SentenceTransformer(
    "flax-sentence-embeddings/all_datasets_v3_mpnet-base"
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]

# %%
retriever
# Out:
# SentenceTransformer(
#   (0): Transformer({'transformer_task': 'feature-extraction', 'modality_config': {'text': {'method': 'forward', 'method_output_name': 'last_hidden_state'}}, 'module_output_name': 'token_embeddings', 'architecture': 'MPNetModel'})
#   (1): Pooling({'embedding_dimension': 768, 'pooling_mode': 'mean', 'include_prompt': True})
#   (2): Normalize({})
# )

# %%
# Create Pinecone Index
pc.create_index("medium-datas", dimension= 768, metric="cosine",
                     spec=ServerlessSpec(cloud="aws", region="us-east-1"))
# Out:
# {
#     "name": "medium-datas",
#     "metric": "cosine",
#     "host": "medium-datas-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 768,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "ab1dc190dfa457544affc58c7c866d0f",
#             "date": "Mon, 27 Apr 2026 18:36:52 GMT",
#             "server": "Google Frontend",
#             "content-length": "393",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
index= pc.Index("medium-datas")

# %% [markdown]
# ### Data Prep

# %%
# !pip uninstall pyarrow -y
# !pip install pyarrow==15.0.2

# %%
import pyarrow
import pyarrow.dataset as pds
print(pyarrow.__version__)
print("pyarrow dataset works")
# Out:
# 15.0.2
# pyarrow dataset works

# %%
# !pip install datasets
from datasets import load_dataset

# %%
# Obtain Raw Data

# df = load_dataset(
#     "fabiochiu/medium-articles",
#     data_files="medium_articles.csv",
#     split="train"
# ).to_pandas()

# df = df.dropna().sample(10000, random_state=45) # might take 30mins to 1hr

# df['text_extended'] = df['title'] + '.' + df['text'].str[:1000]

df = load_dataset(
    "fabiochiu/medium-articles",
    data_files="medium_articles.csv",
    split="train"
).to_pandas()

df = df.dropna().sample(10000, random_state=45)

df['text_extended']= df['title'] +'.'+df['text'].str[:1000]

# %%
# Incase your internet is slow and couldn't make "dataset" works, you can download the file I uploaded as "medium_articles_10k.csv"
# Source of data: https://www.kaggle.com/code/fabiochiusano/medium-articles-simple-data-analysis?select=medium_articles.csv
# it is the same underlying data

# import pandas as pd
# df = pd.read_csv("medium_articles_10k.csv")
# df = df.dropna().sample(1000, random_state=45) # 
# df['text_extended'] = df['title'] + '.' + df['text'].str[:1000]

import pandas as pd

df = pd.read_csv("medium_articles_10k.csv")
df = df.dropna().sample(1000, random_state=45)
df['text_extended'] = df['title']+'.'+df['text'].str[:1000]

# %%
df = df.iloc[0:10000]

# %%
df.head()
# Out:
#       Unnamed: 0                                              title  \
# 3577        3577  Why You’re Struggling with Innovation. And How...
# 7003        7003  #085 | Debugging Vue Sites Displaying Blank Pages
# 925          925  You won’t believe what I’m going to tell you a...
# 3233        3233  How Emotionally Intelligent People Deal With T...
# 3515        3515       What’s New in React 16 and Fiber Explanation
#
#                                                    text  \
# 3577  The modern typewriter had a problem. When Chri...
# 7003  So I had this bright idea to consolidate all m...
# 925   You won’t believe what I’m going to tell you a...
# 3233  This reminds me of the time I was on the way h...
# 3515  Previously, React would block the entire threa...
#
#                                                     url              authors  \
# 3577  https://jswilder16.medium.com/why-youre-strugg...      ['Jake Wilder']
# 7003  https://medium.com/footprints-on-the-sand/085-...      ['Kelvin Zhao']
# 925   https://medium.com/pnewton84/he-discovered-a-n...      ['Paul Newton']
# 3233  https://medium.com/curious/how-emotionally-int...  ['Ayodeji Awosika']
# 3515  https://medium.com/edge-coders/react-16-featur...     ['Trey Huffine']
#
#                              timestamp  \
# 3577  2019-04-22 01:46:42.469000+00:00
# 7003  2020-03-24 23:11:00.960000+00:00
# 925   2017-09-19 19:26:41.376000+00:00
# 3233  2020-11-09 20:50:40.841000+00:00
# 3515  2018-10-30 13:57:05.603000+00:00
#
#                                                    tags  \
# 3577  ['Management', 'Leadership', 'Innovation', 'Cr...
# 7003  ['Vuejs', 'Website Development', 'Debugging', ...
# 925   ['Marketing', 'Digital Marketing', 'Facebook',...
# 3233  ['Emotional Intelligence', 'Mental Health', 'I...
# 3515  ['Code', 'Tech', 'React', 'JavaScript', 'Start...
#
#                                           text_extended
# 3577  Why You’re Struggling with Innovation. And How...
# 7003  #085 | Debugging Vue Sites Displaying Blank Pa...
# 925   You won’t believe what I’m going to tell you a...
# 3233  How Emotionally Intelligent People Deal With T...
# 3515  What’s New in React 16 and Fiber Explanation.P...

# %%
df_batch = df['text_extended'].iloc[0]
df_batch
# Out:
# 'Why You’re Struggling with Innovation. And How to Get Better..The modern typewriter had a problem. When Christopher Sholes developed the first model in 1868, it was an amazing development for its time. But if you tried to type too quickly on it, the type bars had a tendency to bang into one another and get stuck.\n\nSholes consulted an educator who helped him analyze the most common pairings of letters. He then split up those letters so that their type bars were farther apart and less likely to jam.\n\nHe slowed down typing speed to prevent the typewriter from jamming. Which then sped up the typing.\n\nThis dictated the layout of the keyboard, which came to be known for the first six letters in the upper row — QWERTY.\n\nIn 1873, the Sholes & Glidden typewriter became the first to be mass-produced, and its keyboard layout soon became standard. Nearly 150 years later, despite the fact that sticking type bars are an obsolete problem, the original inefficient design continues to be the standard.\n\nIt’s a telling lesson in the power of inertia. And in the bar'

# %%
 [item['word'] for item in nlp(df_batch)]# list of entities
# Out:
# ['Christopher Sholes', 'Sholes', 'QWERTY', 'Sholes & Glidden']

# %%
df_batchs = df['text_extended'].iloc[0:4].tolist()
df_batchs
# Out:
# ['Why You’re Struggling with Innovation. And How to Get Better..The modern typewriter had a problem. When Christopher Sholes developed the first model in 1868, it was an amazing development for its time. But if you tried to type too quickly on it, the type bars had a tendency to bang into one another and get stuck.\n\nSholes consulted an educator who helped him analyze the most common pairings of letters. He then split up those letters so that their type bars were farther apart and less likely to jam.\n\nHe slowed down typing speed to prevent the typewriter from jamming. Which then sped up the typing.\n\nThis dictated the layout of the keyboard, which came to be known for the first six letters in the upper row — QWERTY.\n\nIn 1873, the Sholes & Glidden typewriter became the first to be mass-produced, and its keyboard layout soon became standard. Nearly 150 years later, despite the fact that sticking type bars are an obsolete problem, the original inefficient design continues to be the standard.\n\nIt’s a telling lesson in the power of inertia. And in the bar',
#  '#085 | Debugging Vue Sites Displaying Blank Pages.So I had this bright idea to consolidate all my side projects under a common sub-domain — lab. The only reason why I decided to do this is that my DNS records are getting a little messy, with each sub-domain adding a couple of lines. This is purely my OCD at work, I know.\n\nThe Problem\n\nNow, my initial thought was to simply create a lab project, dump all my side projects into separate folders in it, upload them and call it a day. Which sounds fine in theory, except each of these projects is a single-page Vue application with some internal configs set up long ago.\n\nI was hoping I don’t have to go back and compile them again but alas, after I uploaded the site, the sub-folders all turned up as empty pages. I actually spent the next 6 hours trying to debug this issue because there were no console errors, no indication of what went wrong and worst of all, it was a combination of two different things that caused this, which made things that much worst.\n\nI did try to post this issue on StackO',
#  'You won’t believe what I’m going to tell you about clickbait!.You won’t believe what I’m going to tell you about clickbait!\n\nNumber 5 will shock you…\n\nNo matter what your aims are with content marketing, writing a good, eye-catching headline is key to clicks and success. This has resulted in the method of clickbait progressively evolving over the last few years.\n\nClickbait headlines are written, or thumbnails designed, to create intrigue, and in a way so that the audience must click on the link to find out what they’re talking about. Clickbait is compelling because, psychologically, we crave the information which is left out of headlines. And no matter how tacky they read, clickbait headlines successfully tantalise all sorts of people, and in doing so lure massive amounts of traffic to (usually ad heavy) websites.\n\nBut can clickbait be used by public sector organisations? In its rawest form, no. Fake news! Bad! But there are certain techniques that can be employed to increase the likelihood of clicks and conversion, and at the same time raise you',
#  'How Emotionally Intelligent People Deal With Their Problems the Right Way.This reminds me of the time I was on the way home from a mini-vacation. We had dinner at a busy restaurant. I used to work at a kitchen in high school in college. My (then) wife served for a decade. Her mother has been a caterer and her father currently manages a restaurant.\n\nIn short, we’re very patient and understanding when it comes to the kitchen and waitstaff.\n\nAnyway. We sat down and our service was going well to start. Then, time passed. And as time passed, we saw the server less and less. Our meal took so long, and our waiter was so absent, that we had to go to the front of the restaurant and check the status of our meal.\n\nNot only did we not get our food, but we watched as nearly every table around us received theirs in a timely fashion.\n\nWe suspected the waiter may have forgotten to put the order in or made some mistake, which would have been fine had he addressed the situation and, more importantly, addressed us.\n\nI suspect he was either ashamed, afraid, or both. Finally, by']

# %%
entities=[]
for doc in df_batchs:
    entities.append([item['word'] for item in nlp(doc)])

print(entities)
# Out:
# [['Christopher Sholes', 'Sholes', 'QWERTY', 'Sholes & Glidden'], [], [], []]

# %%
nlp(df_batchs[0])
# Out:
# [{'entity_group': 'PER',
#   'score': 0.99902153,
#   'word': 'Christopher Sholes',
#   'start': 104,
#   'end': 122},
#  {'entity_group': 'PER',
#   'score': 0.9985745,
#   'word': 'Sholes',
#   'start': 316,
#   'end': 322},
#  {'entity_group': 'MISC',
#   'score': 0.90234596,
#   'word': 'QWERTY',
#   'start': 714,
#   'end': 720},
#  {'entity_group': 'ORG',
#   'score': 0.98406315,
#   'word': 'Sholes & Glidden',
#   'start': 736,
#   'end': 752}]

# %%
len(nlp(df_batch)) # list of lst
# Out:
# 4

# %%
len(nlp(df_batchs))
# Out:
# 4

# %% [markdown]
# ### NER Helper Function

# %%
# helper function for extracting entities of a batch of texts

def extract_entities(list_of_text):
    entities = []
    for doc in list_of_text: 
        entities.append([item['word'] for item in nlp(doc)])
        # list of entities for 1 doc
    return entities

# %%
# embedding

len(retriever.encode(df_batch))
# Out:
# 768

# %%
retriever.encode(df_batch).tolist()
# Out:
# [0.05938209220767021,
#  -0.05587984621524811,
#  -0.00025684060528874397,
#  -0.022576093673706055,
#  -0.022538116201758385,
#  0.014586560428142548,
#  0.05134730786085129,
#  0.01942661963403225,
#  0.0004563210532069206,
#  0.005636707413941622,
#  0.01094143558293581,
#  -0.025676017627120018,
#  -0.0052114748395979404,
#  0.07836558669805527,
#  -0.02873675525188446,
#  0.010479453951120377,
#  0.007388378493487835,
#  0.015391374938189983,
#  -0.003297272836789489,
#  0.03341612219810486,
#  0.03883333131670952,
#  -0.009255506098270416,
#  -0.029266050085425377,
#  0.007247708272188902,
#  0.03285254165530205,
#  0.0033398510422557592,
#  0.008476488292217255,
#  -0.03049289621412754,
#  -0.03677905350923538,
#  0.008160448633134365,
#  -0.042663950473070145,
#  0.07858201861381531,
#  -0.029105117544531822,
#  -0.001153979916125536,
#  3.3559519607706534e-08,
#  -0.01684730127453804,
#  0.022535035386681557,
#  0.00914553739130497,
#  -0.049101125448942184,
#  0.059200216084718704,
#  0.032806314527988434,
#  0.041669685393571854,
#  -0.0028220387175679207,
#  0.07893193513154984,
#  0.011920992285013199,
#  0.007947850972414017,
#  -0.04923646152019501,
114, -0.048473432660102844, -0.022990288212895393, 0.06111005321145058, -0.03265446797013283, -0.004631152842193842, -0.017781341448426247, -0.010287721641361713, 0.030464451760053635, -0.03427991271018982, 0.000762822397518903, 0.013734894804656506, -0.026345882564783096, 0.025640415027737617, -0.004241144750267267, 0.028436467051506042, 0.013079524040222168, -0.06382476538419724, -0.018840990960597992, -0.011011024937033653, 0.012710406444966793, -0.09418324381113052, 0.008193574845790863, -0.04707470163702965, -0.04154888540506363, -0.009705869480967522, 0.02186214178800583, -0.036390867084264755, -0.051379237323999405, -0.030715906992554665, 0.011240588501095772, -0.08099105209112167, -0.002941637299954891, -0.08323826640844345, 0.027695050463080406, -0.017440062016248703, -0.01741332747042179, -0.06045473366975784, -0.0069790976122021675, -0.0036627650260925293, -0.0012606793316081166, -0.0038891800213605165, 0.007446627598255873, 0.04832346737384796, 0.041013095527887344, 0.022658048197627068, 0.007965346798300743, -0.006473729852586985, -0.02893463894724846, -0.0774388462305069, 0.04129018262028694, 0.0960833877325058, 0.04179970547556877, -0.013758188113570213, 0.0847419872879982, 0.06556268781423569, 0.012352918274700642, 0.11738426983356476, 0.08791866153478622, -0.0688449814915657, -0.03736601024866104, -0.00907957 ...

# %% [markdown]
# ### Batch Upsert

# %%
# upsert data

# from tqdm.auto import tqdm

from tqdm.auto import tqdm

# batch_size = 64

# for i in range(0, len(df), batch_size):
#     i_end = min(i+batch_size, len(df))
#     # print(i, i_end) # starting and ending index of each batch

batch_size = 64
for i in range(0, len(df), batch_size):
    i_end = min(i+batch_size, len(df))
    print(i, i_end)  # starting and ending index of each batch
    
    # get a batch of data
    # df_batch = df.iloc[i: i_end].copy()
    df_batch = df.iloc[i: i_end].copy()
    
    # embedding
    # emb = retriever.encode(df_batch['text_extended'].tolist()
    #                       ).tolist() # array to python list
    emb = retriever.encode(df_batch['text_extended'].tolist()
                          ).tolist()
    
    # ner extraction
    # entities = extract_entities(df_batch['text_extended'].tolist())
    entities = extract_entities(df_batch['text_extended'].tolist())
    
    # [[]] --> [set1, set2, ], remove duplicate entities    
    # df_batch['named_entity'] = [list(set(entity)) for entity in entities] # one list per document

    df_batch['named_entity'] = [list(set(entity)) for entity in entities]
    # create meta data
    # df_batch = df_batch.drop('text', axis=1)
    df_batch = df_batch.drop('text', axis=1)
    
    # meta_data = df_batch.to_dict(orient='records') # pd.df to dictionary

    meta_data = df_batch.to_dict(orient ='records')
    # create ids
    
    # ids = [f"{idx}" for idx in range(i, i_end)] #

    ids = [f"{idx}" for idx in range(i, i_end)]
    # upsert
    
    # vectors_to_upsert = list(zip(ids, emb, meta_data))  # nd array to python list

    vectors_to_upsert = list(zip(ids, emb, meta_data))
    # _ = index.upsert(vectors= vectors_to_upsert)  
    
    _ = index.upsert(vectors = vectors_to_upsert)
# Out:
# 0 64
# 64 128
# 128 192
# 192 256
# 256 320
# 320 384
# 384 448
# 448 512
# 512 576
# 576 640
# 640 704
# 704 768
# 768 832
# 832 896
# 896 960
# 960 1000

# %%
index.describe_index_stats()
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '187',
#                                     'content-type': 'application/json',
#                                     'date': 'Mon, 04 May 2026 10:28:01 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '44',
#                                     'x-pinecone-request-latency-ms': '44',
#                                     'x-pinecone-response-duration-ms': '45'}},
#  'dimension': 768,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'__default__': {'vector_count': 1000}},
#  'storageFullness': 0.0,
#  'total_vector_count': 1000,
#  'vector_type': 'dense'}

# %% [markdown]
# ### Query data

# %%
# query = "How to make a Wordpress website?"  # Natural Language

# emb_qx = retriever.encode(query).tolist() # embedded query vector

# ne = extract_entities([query])[0]# Named entity as a search filter


query = "how to make a wordpress website?"
emb_qx = retriever.encode(query).tolist()
ne = extract_entities([query])[0]

# %%
# xc = index.query(vector=emb_qx, top_k= 5, include_metadata=True,
#            filter = {"named_entity": {"$in" : ne}})

xc = index.query(vector=emb_qx, top_k = 5, include_metadata=True,
                filter = {"named_entity":{"$in": ne}})

# %%
# you might not find any match if you are only upserting 1k data because of insufficient data there might not be good match, 
# try to load more data or tweak query based on data (glance over pinecone console and look for text_extended field in your vectors)
# for result in xc['matches']:
#     print(result['score'], " ", result['metadata']['named_entity'])


for result in xc['matches']:
    print(result['score'], " ", result['metadata']['named_entity'])
# Out:
# 0.283930779   ['NLP', 'Allen NLP', 'PyTorch', 'Allen']
# 0.26279068   ['Harnham', 'Data', 'Datatech Analytics', 'NLP', 'London', 'LDA', 'Python', 'Science']
# 0.242308617   ['Lambda Layer', 'NLP']
# 0.237251282   ['It', 'Text Mining', 'The Shining', 'Stephen King', 'King', 'NLP', 'Carrie', 'Under the Dome', 'The Dark Tower']
# 0.211456299   ['Your Weekly AI', 'NLP', 'Machine Learning and Data Science', 'AI', 'ML']

# %%
# query = "How to learn NLP?"  # Natural Language

# emb_qx = retriever.encode(query).tolist() # embedded query vector

# ne = extract_entities([query])[0] # Named entity as a search filter

# xc = index.query(vector=emb_qx, top_k= 5, include_metadata=True,
#            filter = {"named_entity": {"$in" : ne}  })


query = "how to learn NLP?"
emb_qx = retriever.encode(query).tolist()
ne = extract_entities([query])[0]
xc = index.query(vector=emb_qx, top_k=5, include_metadata=True,
filter = {"named_entity":{"$in":ne}})

# %%
# for result in xc['matches']:
#     print(result['score'], " ", result['metadata']['named_entity'])


for result in xc['matches']:
    print(result['score'], " ", result['metadata']['named_entity'])
# Out:
# 0.283930779   ['NLP', 'Allen NLP', 'PyTorch', 'Allen']
# 0.26279068   ['Harnham', 'Data', 'Datatech Analytics', 'NLP', 'London', 'LDA', 'Python', 'Science']
# 0.242308617   ['Lambda Layer', 'NLP']
# 0.237251282   ['It', 'Text Mining', 'The Shining', 'Stephen King', 'King', 'NLP', 'Carrie', 'Under the Dome', 'The Dark Tower']
# 0.211456299   ['Your Weekly AI', 'NLP', 'Machine Learning and Data Science', 'AI', 'ML']
