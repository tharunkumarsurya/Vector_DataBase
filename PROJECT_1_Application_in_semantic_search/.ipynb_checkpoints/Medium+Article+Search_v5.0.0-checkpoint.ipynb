# %% [markdown]
# # Medium Article Semantic Search by Title+Subtitle

# %% [markdown]
# ### Load Data

# %%
import pandas as pd

# %%
df = pd.read_csv("medium_post_titles.csv", nrows=10000) # excercise whole data set
# data source: https://www.kaggle.com/datasets/nulldata/medium-post-titles

# %%
df.head()
# Out:
#                   category                                              title  \
# 0                     work  "21 Conversations" - A fun (and easy) game for...
# 1             spirituality                       "Biblical Porn" at Mars Hill
# 2                  lgbtqia                  "CISGENDER?! Is That A Disease?!"
# 3                 equality  "Call me Nat Love" :Black Cowboys and the Fron...
# 4  artificial-intelligence           "Can I Train my Model on Your Computer?"
#
#                                             subtitle  subtitle_truncated_flag
# 0  A (new?) Icebreaker game to get your team to s...                    False
# 1  Author and UW lecturer Jessica Johnson talks a...                    False
# 2  Or, a primer in gender vocabulary for the curi...                    False
# 3                                                NaN                    False
# 4  How we waste computational resources and how t...                    False

# %%
# df["subtitle_truncated_flag"].value_counts()
df["subtitle_truncated_flag"].value_counts()
# Out:
# subtitle_truncated_flag
# False    6318
# True     3682
# Name: count, dtype: int64

# %% [markdown]
# ### Data Cleanup

# %%
# # df.isna().sum()

# df = df.dropna()
# df = df[~df["subtitle_truncated_flag"]]
# # df["subtitle_truncated_flag"].value_counts()

# df['title_extended'] = df['title'] + df['subtitle']

df.isna().sum()
# Out:
# category                     0
# title                        0
# subtitle                   107
# subtitle_truncated_flag      0
# dtype: int64

# %%
df = df.dropna()

# %%
df1 = df[~df["subtitle_truncated_flag"]]
# print(df1)

# %%
df["subtitle_truncated_flag"].value_counts()
# Out:
# subtitle_truncated_flag
# False    6211
# True     3682
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (9893, 4)

# %%
df["title_extended"] = df["title"]+df["subtitle"]

# %%
df.head()
# Out:
#                   category                                              title  \
# 0                     work  "21 Conversations" - A fun (and easy) game for...
# 1             spirituality                       "Biblical Porn" at Mars Hill
# 2                  lgbtqia                  "CISGENDER?! Is That A Disease?!"
# 4  artificial-intelligence           "Can I Train my Model on Your Computer?"
# 5           cryptocurrency  "Cypherpunks and Wall Street": The Security To...
#
#                                             subtitle  subtitle_truncated_flag  \
# 0  A (new?) Icebreaker game to get your team to s...                    False
# 1  Author and UW lecturer Jessica Johnson talks a...                    False
# 2  Or, a primer in gender vocabulary for the curi...                    False
# 4  How we waste computational resources and how t...                    False
# 5  Bruce Fenton presents at the World Blockchain ...                    False
#
#                                       title_extended
# 0  "21 Conversations" - A fun (and easy) game for...
# 1  "Biblical Porn" at Mars HillAuthor and UW lect...
# 2  "CISGENDER?! Is That A Disease?!"Or, a primer ...
# 4  "Can I Train my Model on Your Computer?"How we...
# 5  "Cypherpunks and Wall Street": The Security To...

# %%
# df.head()
# df['category'].nunique()  # metadata
# df.shape # 6k vectors, full set in excercise

df["category"].nunique()
# Out:
# 93

# %%
df.shape
# Out:
# (9893, 5)

# %%
df.head()
# Out:
#                   category                                              title  \
# 0                     work  "21 Conversations" - A fun (and easy) game for...
# 1             spirituality                       "Biblical Porn" at Mars Hill
# 2                  lgbtqia                  "CISGENDER?! Is That A Disease?!"
# 4  artificial-intelligence           "Can I Train my Model on Your Computer?"
# 5           cryptocurrency  "Cypherpunks and Wall Street": The Security To...
#
#                                             subtitle  subtitle_truncated_flag  \
# 0  A (new?) Icebreaker game to get your team to s...                    False
# 1  Author and UW lecturer Jessica Johnson talks a...                    False
# 2  Or, a primer in gender vocabulary for the curi...                    False
# 4  How we waste computational resources and how t...                    False
# 5  Bruce Fenton presents at the World Blockchain ...                    False
#
#                                       title_extended
# 0  "21 Conversations" - A fun (and easy) game for...
# 1  "Biblical Porn" at Mars HillAuthor and UW lect...
# 2  "CISGENDER?! Is That A Disease?!"Or, a primer ...
# 4  "Can I Train my Model on Your Computer?"How we...
# 5  "Cypherpunks and Wall Street": The Security To...

# %% [markdown]
# ### Prep for Upsert

# %%
# API_KEY =""

# %%
# init pinecone
from pinecone import Pinecone, ServerlessSpec
# API_KEY = "YOUR API KEY"
pc = Pinecone(api_key = API_KEY)

# %%
# pc.create_index(name = "medium-data", 
#                 dimension=384, 
#                 metric="cosine",
#                 spec=ServerlessSpec(
#                     cloud="aws",
#                     region="us-east-1"
#                 )) # remember to use only us-east-1 in free tier


pc.create_index(name="medium-dates",
               dimension=384,
               metric="cosine",
               spec=ServerlessSpec(
                   cloud="aws",
                   region="us-east-1"
               ))
# Out:
# {
#     "name": "medium-dates",
#     "metric": "cosine",
#     "host": "medium-dates-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 384,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "7415850fc4337a6124dae87ddd41eaa3",
#             "date": "Mon, 27 Apr 2026 10:13:49 GMT",
#             "server": "Google Frontend",
#             "content-length": "393",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "hello-pinecone",
#         "metric": "cosine",
#         "host": "hello-pinecone-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "test",
#         "metric": "cosine",
#         "host": "test-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 3,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "medium-date",
#         "metric": "cosine",
#         "host": "medium-date-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 384,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "insert",
#         "metric": "cosine",
#         "host": "insert-kbs8m4f.svc.apw5-4e34-81fa.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-west-2",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 4,
#         "deletion_protection": "disabled",
#         "tags": null
#     }
# ]

# %%
# pinecone.create_index(name='medium-data', dimension=384, pod_type='s1', metric="cosine" )

# %%
# !pip install sentence-transformers

# %%
# !python -m pip install --upgrade pip

# %%
# !pip install tf-keras

# %%
# !pip install --upgrade transformers sentence-transformers tensorflow tf-keras

# %%
from sentence_transformers import SentenceTransformer
import torch

# %%
# !pip install ipywidgets

# %%
from sentence_transformers import SentenceTransformer

print("Loading model...")
model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
print("Model loaded successfully")
# Out:
# Loading model...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Model loaded successfully

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')# cuda or cpu
# model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# !python -m pip install torch torchvision torchaudio

# %%
# !pip uninstall torch torchvision torchaudio -y
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.11.0+cpu
# False

# %%
df.head()
# Out:
#                   category                                              title  \
# 0                     work  "21 Conversations" - A fun (and easy) game for...
# 1             spirituality                       "Biblical Porn" at Mars Hill
# 2                  lgbtqia                  "CISGENDER?! Is That A Disease?!"
# 4  artificial-intelligence           "Can I Train my Model on Your Computer?"
# 5           cryptocurrency  "Cypherpunks and Wall Street": The Security To...
#
#                                             subtitle  subtitle_truncated_flag  \
# 0  A (new?) Icebreaker game to get your team to s...                    False
# 1  Author and UW lecturer Jessica Johnson talks a...                    False
# 2  Or, a primer in gender vocabulary for the curi...                    False
# 4  How we waste computational resources and how t...                    False
# 5  Bruce Fenton presents at the World Blockchain ...                    False
#
#                                       title_extended
# 0  "21 Conversations" - A fun (and easy) game for...
# 1  "Biblical Porn" at Mars HillAuthor and UW lect...
# 2  "CISGENDER?! Is That A Disease?!"Or, a primer ...
# 4  "Can I Train my Model on Your Computer?"How we...
# 5  "Cypherpunks and Wall Street": The Security To...

# %%
# df['values'] = df['title_extended'].map(
#     lambda x: (model.encode(x)).tolist()) # python list, 6k rows 1 min

df['values'] = df['title_extended'].map(
    lambda x: (model.encode(x)).tolist())

# %%
df.head()
# Out:
#                   category                                              title  \
# 0                     work  "21 Conversations" - A fun (and easy) game for...
# 1             spirituality                       "Biblical Porn" at Mars Hill
# 2                  lgbtqia                  "CISGENDER?! Is That A Disease?!"
# 4  artificial-intelligence           "Can I Train my Model on Your Computer?"
# 5           cryptocurrency  "Cypherpunks and Wall Street": The Security To...
#
#                                             subtitle  subtitle_truncated_flag  \
# 0  A (new?) Icebreaker game to get your team to s...                    False
# 1  Author and UW lecturer Jessica Johnson talks a...                    False
# 2  Or, a primer in gender vocabulary for the curi...                    False
# 4  How we waste computational resources and how t...                    False
# 5  Bruce Fenton presents at the World Blockchain ...                    False
#
#                                       title_extended  \
# 0  "21 Conversations" - A fun (and easy) game for...
# 1  "Biblical Porn" at Mars HillAuthor and UW lect...
# 2  "CISGENDER?! Is That A Disease?!"Or, a primer ...
# 4  "Can I Train my Model on Your Computer?"How we...
# 5  "Cypherpunks and Wall Street": The Security To...
#
#                                               values
# 0  [-0.031074360013008118, -0.014303414151072502,...
# 1  [-0.03467034548521042, -0.018165316432714462, ...
# 2  [0.03740720450878143, -0.0008568223565816879, ...
# 4  [-0.013686500489711761, 0.004296017810702324, ...
# 5  [-0.031468793749809265, -0.004646690096706152,...

# %%
# df['id'] = df.reset_index(drop = 'index').index

df['id'] = df.reset_index(drop='index').index

# %%
# df.head()

# %%
# df['metadata'] = df.apply(lambda x: {
#     'title' : x['title'],
#     'subtitle': x['subtitle'],
#     'category': x['category']
    
# }, axis=1)

df['metadata'] = df.apply(lambda x: {
    'title': x['title'],
    'subtitle':x['subtitle'],
    'category':x['category']
}, axis=1)

# %%
# df_upsert = df[['id', 'values', 'metadata']]
df_upsert = df[['id','values','metadata']]

# %%
# df_upsert['id'] = df_upsert['id'].map(lambda x: str(x))
# df_upsert['id'] = df_upsert['id'].map(lambda x: str(x))

# %%
print(pc.list_indexes().names())
print(pc)
from pinecone import Pinecone

# pc = Pinecone(api_key="")
print(pc.list_indexes().names())
# Out:
# ['hello-pinecone', 'test', 'medium-date', 'insert']
# <pinecone.pinecone.Pinecone object at 0x0000017313BF28A0>
# ['hello-pinecone', 'test', 'medium-date', 'insert']

# %%
import pinecone
print(pinecone.__version__)
# Out:
# 8.1.2

# %%
from pinecone import ServerlessSpec

pc.create_index(
    name="test2",
    dimension=384,
    metric="cosine",
    spec=ServerlessSpec(
        cloud="aws",
        region="us-east-1"
    )
)
# Out:
# {
#     "name": "test2",
#     "metric": "cosine",
#     "host": "test2-kbs8m4f.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 384,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "_response_info": {
#         "raw_headers": {
#             "content-type": "application/json",
#             "vary": "origin, access-control-request-method, access-control-request-headers",
#             "access-control-allow-origin": "*",
#             "access-control-expose-headers": "*",
#             "x-pinecone-api-version": "2025-10",
#             "x-cloud-trace-context": "f09cdc20ce5ce6e517c3bce3b0377849",
#             "date": "Mon, 27 Apr 2026 10:21:55 GMT",
#             "server": "Google Frontend",
#             "content-length": "379",
#             "via": "1.1 google",
#             "alt-svc": "h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000"
#         }
#     }
# }

# %%
from pinecone import Pinecone
# pc=Pinecone(api_key="")

# %%
index =pc.Index("test2")

# %%
index.upsert_from_dataframe(df_upsert) # 6k takes 1 min
# Out:
# sending upsert requests:   0%|          | 0/9893 [00:00<?, ?it/s]
# UpsertResponse(upserted_count=9893, _response_info={'raw_headers': {'date': 'Mon, 27 Apr 2026 10:25:11 GMT', 'content-type': 'application/json', 'content-length': '21', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '20', 'x-pinecone-request-logical-size': '679810', 'x-pinecone-request-latency-ms': '2211', 'x-envoy-upstream-service-time': '224', 'x-pinecone-response-duration-ms': '2213', 'grpc-status': '0', 'server': 'envoy'}})

# %% [markdown]
# ### Query

# %%
xc = index.query(vector=(model.encode("which city is the most beautiful")).tolist(), # python list
           top_k=10,
           include_metadata=True)

# xc = index.query(vector=(model.encode("which city is the most beautifull")).tolist(),
#                 top_k=10,
#                 include_metadata=True)

# %%
# for result in xc['matches']:
#     print(f"{round(result['score'], 2)}: {result['metadata']['title']}: {result['metadata']['category']} ")

for result in xc['matches']:
    print(f"{round(result['score'],2)}: {result['metadata']['title']}: {result['metadata']['category']}")
# Out:
# 0.57: 3 Places Where You Can Find Beauty: photography
# 0.46: 6 Easy Reasons to Enjoy Exploring South Wales: travel
# 0.45: A City That’s Better for the Blind Is Better for Everyone: accessibility
# 0.45: A Shining City on a Hill: politics
# 0.44: A Just City is a Healthy City: environment
# 0.42: A Most Beautiful Game: sports
# 0.41: A Case For Preserving History: education
# 0.4: 6 Literary Cities for Book Lovers To Visit This Year: travel
# 0.4: Ace Hotel: A UX Case Study: ux
# 0.39: A city and its architecture: cities

# %%
for result in xc['matches']:
    print(f"{round(result['score'], 2)}: {result['metadata']['subtitle']}: {result['metadata']['category']} ")
# Out:
# 0.57: If you are willing to look hard enough, eventually you will see beauty in the most difficult of places.: photography
# 0.46: Pembrokeshire is as beautiful as the Italian Coast.: travel
# 0.45: Complete parity with the sighted may seem like an impossible goal, but maybe the only thing holding us back is a lack of imagination.: accessibility
# 0.45: What does America stand for?: politics
# 0.44: At CultureHouse, we believe that urban design can be used for the common good, and that good design should be an essential part of the: environment
# 0.42: The World Cup gets advertising right: sports
# 0.41: I am fortunate to live in a town that is both beautiful and historic. When I say historic, I mean, of course, from an American perspective: education
# 0.4: Combine your love for books and travel with these 6 literary cities.: travel
# 0.4: Discover the city you are visting like a local: ux
# 0.39: Bangalore Chapter: cities

# %% [markdown]
# ### Excercise: Upsert all data

# %%
df.head()
# Out:
#                   category                                              title  \
# 0                     work  "21 Conversations" - A fun (and easy) game for...
# 1             spirituality                       "Biblical Porn" at Mars Hill
# 2                  lgbtqia                  "CISGENDER?! Is That A Disease?!"
# 4  artificial-intelligence           "Can I Train my Model on Your Computer?"
# 5           cryptocurrency  "Cypherpunks and Wall Street": The Security To...
#
#                                             subtitle  subtitle_truncated_flag  \
# 0  A (new?) Icebreaker game to get your team to s...                    False
# 1  Author and UW lecturer Jessica Johnson talks a...                    False
# 2  Or, a primer in gender vocabulary for the curi...                    False
# 4  How we waste computational resources and how t...                    False
# 5  Bruce Fenton presents at the World Blockchain ...                    False
#
#                                       title_extended  \
# 0  "21 Conversations" - A fun (and easy) game for...
# 1  "Biblical Porn" at Mars HillAuthor and UW lect...
# 2  "CISGENDER?! Is That A Disease?!"Or, a primer ...
# 4  "Can I Train my Model on Your Computer?"How we...
# 5  "Cypherpunks and Wall Street": The Security To...
#
#                                               values  id  \
# 0  [-0.031074360013008118, -0.014303414151072502,...   0
# 1  [-0.03467034548521042, -0.018165316432714462, ...   1
# 2  [0.03740720450878143, -0.0008568223565816879, ...   2
# 4  [-0.013686500489711761, 0.004296017810702324, ...   3
# 5  [-0.031468793749809265, -0.004646690096706152,...   4
#
#                                             metadata
# 0  {'title': '"21 Conversations" - A fun (and eas...
# 1  {'title': '"Biblical Porn" at Mars Hill', 'sub...
# 2  {'title': '"CISGENDER?! Is That A Disease?!"',...
# 4  {'title': '"Can I Train my Model on Your Compu...
# 5  {'title': '"Cypherpunks and Wall Street": The ...
